# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD
from concurrent.futures import ThreadPoolExecutor

# %%
# 1. Thread Configuration for Concurrency
tf.config.threading.set_intra_op_parallelism_threads(1)
tf.config.threading.set_inter_op_parallelism_threads(1)
print("Environment set. TF restricted to 1 thread per instance to allow concurrency.")
# Out:
# Environment set. TF restricted to 1 thread per instance to allow concurrency.

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.astype(np.float32) / 255.0
X_test = X_test.astype(np.float32) / 255.0
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %%
def iid_partition(x, y, num_clients):
    idx = np.random.permutation(len(x))
    x_shuffled, y_shuffled = x[idx], y[idx]
    x_parts = np.array_split(x_shuffled, num_clients)
    y_parts = np.array_split(y_shuffled, num_clients)
    partitions = list(zip(x_parts, y_parts))
    return partitions

# %%
def non_iid_partition(x, y, num_clients):
    sorted_idx = np.argsort(y)
    X_sorted, Y_sorted = x[sorted_idx], y[sorted_idx]
    num_shards = 2 * num_clients
    size_shards = len(x) // num_shards
    shards_idx = np.random.permutation(num_shards)
    partitions = []
    for i in range(num_clients):
        s1, s2 = shards_idx[2*i], shards_idx[2*i+1]
        X_client = np.concatenate((X_sorted[s1*size_shards:(s1+1)*size_shards], X_sorted[s2*size_shards:(s2+1)*size_shards]), axis=0)
        Y_client = np.concatenate((Y_sorted[s1*size_shards:(s1+1)*size_shards], Y_sorted[s2*size_shards:(s2+1)*size_shards]), axis=0)
        idx = np.random.permutation(len(X_client))
        partitions.append((X_client[idx], Y_client[idx]))
    return partitions

# %%
# 4. Model Generation
def cnn_model():
    model = Sequential([
        Input(shape=(28, 28, 1)),
        Conv2D(32, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax'),
    ])
    model.compile(optimizer=SGD(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def local_training(client_data, global_weights, mu):
    X_local, Y_local = client_data
    num_sample = len(X_local)
    model = cnn_model()
    model.set_weights(global_weights)
    optimizer = SGD(learning_rate=0.01)
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
    global_weights_tensors = [tf.constant(w) for w in global_weights]
    dataset = tf.data.Dataset.from_tensor_slices((X_local, Y_local)).batch(32)
    
    def train_step(x, y):
        with tf.GradientTape() as tape:
            y_pred = model(x, training=True)
            base_loss = loss_fn(y, y_pred)
            
            proximal_term = 0.0
            for local_var, global_var in zip(model.trainable_variables, global_weights_tensors):
                proximal_term += tf.reduce_sum(tf.square(local_var - global_var))
                
            total_loss = base_loss + (mu / 2.0) * proximal_term    
        grads = tape.gradient(total_loss, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

    for epoch in range(2):
        for batch_x, batch_y in dataset:
            train_step(batch_x, batch_y)
            
    return model.get_weights(), num_sample

# %%
def aggregate_weights(client_updates, global_weights):
    tot_sample = sum(num_samples for _, num_samples in client_updates)
    new_weights = [np.zeros_like(w) for w in global_weights]
    
    for local_weights, num_samples in client_updates:
        w_factor = num_samples / tot_sample
        for i in range(len(new_weights)):
            new_weights[i] += local_weights[i] * w_factor
            
    return new_weights

# %%
def evaluate_global(global_model, X_test, Y_test):
    loss, accuracy = global_model.evaluate(X_test, Y_test, verbose=1)
    return loss, accuracy

# %%
def run_simulation(partitions, X_test, Y_test, num_clients, rounds, participation_rate, mu):
    global_model = cnn_model()
    global_weights = global_model.get_weights()
    max_workers = min(num_clients, 12)
    history = []
    
    for r in range(1, rounds + 1):
        num_active = max(1, int(num_clients * participation_rate))
        active_clients = random.sample(range(num_clients), num_active)
        client_updates = []
        
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            futures = [executor.submit(local_training, partitions[i], global_weights, mu) for i in active_clients]
            for future in futures:
                client_updates.append(future.result())
                
        # Aggregate and Update
        global_weights = aggregate_weights(client_updates, global_weights)
        global_model.set_weights(global_weights)
        
        # Evaluate
        loss, acc = evaluate_global(global_model, X_test, Y_test)
        history.append({'round': r, 'loss': loss, 'acc': acc})
        print(f"Round {r} | Accuracy: {acc} | Loss: {loss}")
        
    return history

# %%
CLIENTS=10
ROUNDS=20
PARTICIPATION_RATE =1
MU=0.5
    
print(f"=== RUNNING IID FEDPROX ({CLIENTS} Clients, {PARTICIPATION_RATE*100}% Participation) ===")
iid_parts = iid_partition(X_train, Y_train, CLIENTS)
iid_history = run_simulation(iid_parts, X_test, Y_test, CLIENTS, ROUNDS, PARTICIPATION_RATE, MU)
    
print(f"\n=== RUNNING NON-IID FEDPROX ({CLIENTS} Clients, {PARTICIPATION_RATE*100}% Participation) ===")
non_iid_parts = non_iid_partition(X_train, Y_train, CLIENTS)
non_iid_history = run_simulation(non_iid_parts, X_test, Y_test, CLIENTS, ROUNDS, PARTICIPATION_RATE, MU)
# Out:
# === RUNNING IID FEDPROX (10 Clients, 100% Participation) ===
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8327 - loss: 0.7642
# Round 1 | Accuracy: 0.8327000141143799 | Loss: 0.764245867729187
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8865 - loss: 0.4160
# Round 2 | Accuracy: 0.8865000009536743 | Loss: 0.41600868105888367
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9067 - loss: 0.3216
# Round 3 | Accuracy: 0.9067000150680542 | Loss: 0.32158756256103516
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9201 - loss: 0.2741
# Round 4 | Accuracy: 0.9200999736785889 | Loss: 0.2741023302078247
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9291 - loss: 0.2412
# Round 5 | Accuracy: 0.929099977016449 | Loss: 0.24115200340747833
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9361 - loss: 0.2165
# Round 6 | Accuracy: 0.9361000061035156 | Loss: 0.21645832061767578
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9422 - loss: 0.1962
# Round 7 | Accuracy: 0.9422000050544739 | Loss: 0.1962309181690216
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9464 - loss: 0.1795
# Round 8 | Accuracy: 0.946399986743927 | Loss: 0.17953607439994812
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9512 - loss: 0.1654
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9656 - loss: 0.1123
# Round 15 | Accuracy: 0.9656000137329102 | Loss: 0.11234904825687408
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9666 - loss: 0.1069
# Round 16 | Accuracy: 0.9666000008583069 | Loss: 0.10691065341234207
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9684 - loss: 0.1020
# Round 17 | Accuracy: 0.9684000015258789 | Loss: 0.10204281657934189
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9693 - loss: 0.0977
# Round 18 | Accuracy: 0.9692999720573425 | Loss: 0.09774627536535263
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9704 - loss: 0.0938
# Round 19 | Accuracy: 0.9703999757766724 | Loss: 0.09382378309965134
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9714 - loss: 0.0903
# Round 20 | Accuracy: 0.9714000225067139 | Loss: 0.0902545377612114
#
# === RUNNING NON-IID FEDPROX (10 Clients, 100% Participation) ===
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.3521 - loss: 2.1091
# Round 1 | Accuracy: 0.3521000146865845 | Loss: 2.1090707778930664
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.3948 - loss: 1.7971
# Round 2 | Accuracy: 0.39480000734329224 | Loss: 1.7970513105392456
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4799 - loss: 1.5330
# Round 3 | Accuracy: 0.4799000024795532 | Loss: 1.532976746559143
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5722 - loss: 1.3206
# Round 4 | Accuracy: 0.5722000002861023 | Loss: 1.3206108808517456
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6247 - loss: 1.1650
# Round 5 | Accuracy: 0.6247000098228455 | Loss: 1.1649646759033203
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6512 - loss: 1.0592
# Round 6 | Accuracy: 0.651199996471405 | Loss: 1.0591702461242676
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6687 - loss: 0.9796
# Round 7 | Accuracy: 0.6686999797821045 | Loss: 0.9795533418655396
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6828 - loss: 0.9150
# Round 8 | Accuracy: 0.6827999949455261 | Loss: 0.9150040149688721
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6931 - loss: 0.8622
# Round 9 | Accuracy: 0.6930999755859375 | Loss: 0.8621719479560852
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7021 - loss: 0.8184
# Round 10 | Accuracy: 0.7020999789237976 | Loss: 0.818396806716919
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7126 - loss: 0.7804
# Round 11 | Accuracy: 0.7125999927520752 | Loss: 0.7804132103919983
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7205 - loss: 0.7482
# Round 12 | Accuracy: 0.7204999923706055 | Loss: 0.7482092976570129
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7267 - loss: 0.7217
# Round 13 | Accuracy: 0.7267000079154968 | Loss: 0.7216988205909729
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7338 - loss: 0.6968
# Round 14 | Accuracy: 0.7337999939918518 | Loss: 0.696786642074585
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7419 - loss: 0.6722
# Round 15 | Accuracy: 0.7419000267982483 | Loss: 0.6722034215927124
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7492 - loss: 0.6511
# Round 16 | Accuracy: 0.7491999864578247 | Loss: 0.6511289477348328
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7569 - loss: 0.6296
# Round 17 | Accuracy: 0.7569000124931335 | Loss: 0.6295971274375916
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7644 - loss: 0.6119
# Round 18 | Accuracy: 0.7644000053405762 | Loss: 0.6118762493133545
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7719 - loss: 0.5926
# Round 19 | Accuracy: 0.7718999981880188 | Loss: 0.5925779342651367
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7806 - loss: 0.5730
# Round 20 | Accuracy: 0.7806000113487244 | Loss: 0.5729769468307495

# %%
iid_df = pd.DataFrame(iid_history)
non_iid_df = pd.DataFrame(non_iid_history)
    
plt.figure(figsize=(12, 5))
    
plt.subplot(1, 2, 1)
plt.plot(iid_df['round'], iid_df['acc'], marker='o', color='blue', label='Test Accuracy')
plt.plot(iid_df['round'], iid_df['loss'], marker='s', color='orange', label='Test Loss')
plt.title("Adaptive FedProx (IID)")
plt.xlabel("Communication Rounds")
plt.ylabel("Value")
plt.xticks(range(0, ROUNDS + 1, 2))
plt.legend()
plt.grid(True)
    
plt.subplot(1, 2, 2)
plt.plot(non_iid_df['round'], non_iid_df['acc'], marker='o', color='blue', label='Test Accuracy')
plt.plot(non_iid_df['round'], non_iid_df['loss'], marker='s', color='orange', label='Test Loss')
plt.title("Adaptive FedProx (Non-IID)")
plt.xlabel("Communication Rounds")
plt.ylabel("Value")
plt.xticks(range(0, ROUNDS + 1, 2))
plt.legend()
plt.grid(True)
    
plt.tight_layout()
plt.show()
