# %%
import matplotlib.pyplot as plt

def style_plot(ax, max_rounds, step):
    ax.set_xticks(range(0, max_rounds + 1, step))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['bottom'].set_color('#CCCCCC')
    
    ax.grid(axis='y', color='#E0E0E0', linestyle='-')
    ax.grid(axis='x', visible=False)
    
    ax.tick_params(axis='both', which='both', length=0)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2, frameon=False)

# ==========================================
# DATA
# ==========================================

iid_acc = [0.8730999827, 0.9106000066, 0.9283000231, 0.9404000044, 0.9483000040, 0.9548000097, 0.9596999884, 0.9631999731, 0.9661999941, 0.9689000249, 0.9710000157, 0.9732999802, 0.9740999937, 0.9750999808, 0.9765999913, 0.9775999784, 0.9783999920, 0.9789999723, 0.9796000123, 0.9800000191]
iid_loss = [0.5348038077, 0.3166976869, 0.2495007515, 0.2088758051, 0.1798899621, 0.1580309272, 0.1407034248, 0.1268360615, 0.1154449806, 0.1061868742, 0.0984557569, 0.0920683146, 0.0865588039, 0.0818089992, 0.0778674111, 0.0743337348, 0.0713631809, 0.0686866567, 0.0663236231, 0.0641557723]
iid_rounds = list(range(1, len(iid_acc) + 1))

non_iid_acc = [0.2552999854, 0.4620000124, 0.5803999901, 0.6464999914, 0.7057999969, 0.7487999797, 0.7797999978, 0.8055999875, 0.8216000199, 0.8345000148, 0.8482000232, 0.8575999737, 0.8636000156, 0.8708999753, 0.8763999939, 0.8824999928, 0.8859000206, 0.8895000219, 0.8919000030, 0.8942999840, 0.9013000131, 0.9035000205, 0.9059000015, 0.9071999788, 0.9092000127, 0.9106000066, 0.9128999710, 0.9143000245, 0.9168000221, 0.9178000093, 0.9183999896, 0.9190000296, 0.9204999804, 0.9210000038, 0.9222999811, 0.9235000014, 0.9243000150, 0.9251000285, 0.9261000156, 0.9265999794, 0.9271000028, 0.9280999899, 0.9291999936, 0.9297000170, 0.9311000109, 0.9318000078, 0.9320000410, 0.9320000410, 0.9319999814, 0.9323999882]
non_iid_loss = [2.0616993904, 1.5750088692, 1.2423703671, 1.0278004408, 0.8707041144, 0.7536744475, 0.6656271219, 0.5985773206, 0.5485447049, 0.5089980364, 0.4773024023, 0.4479187131, 0.4258404374, 0.4064290524, 0.3897058964, 0.3745402098, 0.3624267876, 0.3512571156, 0.3415727317, 0.3321202397, 0.3156007826, 0.3081434369, 0.3008608520, 0.2944563925, 0.2888498902, 0.2833929956, 0.2772725523, 0.2724186182, 0.2671048641, 0.2624594569, 0.2586889565, 0.2542927861, 0.2507443726, 0.2474291026, 0.2416781783, 0.2383772284, 0.2354760468, 0.2326240689, 0.2302247137, 0.2275565416, 0.2248865515, 0.2220987529, 0.2198631763, 0.2178714424, 0.2150854468, 0.2133207023, 0.2114959955, 0.2114959955, 0.2114959955, 0.2095416188]
non_iid_rounds = list(range(1, len(non_iid_acc) + 1))

# ==========================================
# 100% PARTICIPATION PLOTS
# ==========================================

# --- 100% IID Plot (20 Rounds, Spacing: 2) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(iid_rounds, iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(iid_rounds, iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title("FedProx Global Performance-IID (100% Participation) $\mu=0.2$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=20, step=2)
plt.tight_layout()
plt.show()

# --- 100% Non-IID Plot (50 Rounds, Spacing: 5) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(non_iid_rounds, non_iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(non_iid_rounds, non_iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title("FedProx Global Performance-Non-IID (100% Participation) $\mu=0.2$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=50, step=5)
plt.tight_layout()
plt.show()
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\m'
# <>:47: SyntaxWarning: invalid escape sequence '\m'
# <>:36: SyntaxWarning: invalid escape sequence '\m'
# <>:47: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\golu3\AppData\Local\Temp\ipykernel_21920\1086263806.py:36: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_title("FedProx Global Performance-IID (100% Participation) $\mu=0.2$", pad=15, fontsize=12)
# C:\Users\golu3\AppData\Local\Temp\ipykernel_21920\1086263806.py:47: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_title("FedProx Global Performance-Non-IID (100% Participation) $\mu=0.2$", pad=15, fontsize=12)

# %%
def style_plot(ax, max_rounds, step):
    ax.set_xticks(range(0, max_rounds + 1, step))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['bottom'].set_color('#CCCCCC')
    
    ax.grid(axis='y', color='#E0E0E0', linestyle='-')
    ax.grid(axis='x', visible=False)
    
    ax.tick_params(axis='both', which='both', length=0)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2, frameon=False)

# ==========================================
# DATA (50% Participation, mu=0.2)
# ==========================================

# IID Data (50 Rounds)
iid_acc = [
    0.8501999974, 0.9006999731, 0.9221000075, 0.9355000257, 0.9393000007, 0.9491000175, 
    0.9562000036, 0.9599999785, 0.9628999829, 0.9654999971, 0.9672999978, 0.9689000249, 
    0.9674999714, 0.9703000188, 0.9718000293, 0.9721999764, 0.9746000171, 0.9746000171, 
    0.9768000245, 0.9751999974, 0.9785000086, 0.9753999710, 0.9781000018, 0.9797999859, 
    0.9789999723, 0.9797000289, 0.9800999761, 0.9786999822, 0.9805999994, 0.9800999761, 
    0.9811999798, 0.9811999798, 0.9824000001, 0.9810000062, 0.9811999798, 0.9824000001, 
    0.9833999872, 0.9811000228, 0.9829000235, 0.9846000075, 0.9815999866, 0.9829999804, 
    0.9842000008, 0.9825000167, 0.9846000075, 0.9843000174, 0.9836999774, 0.9835000038, 
    0.9830999970, 0.9851999879
]

iid_loss = [
    0.6020631790, 0.3440597057, 0.2711368501, 0.2270312756, 0.2088869214, 0.1755691916, 
    0.1480602473, 0.1389341503, 0.1279792786, 0.1159582362, 0.1100943610, 0.1037503779, 
    0.3338535428, 0.6146612763, 0.9826736450, 0.3255046606, 0.4117321670, 0.2751022577, 
    0.2512637675, 0.2763512433, 0.2094430476, 0.4173077047, 0.2662958801, 0.5052291751, 
    0.4726116359, 0.2925971448, 0.4685558081, 0.4039778113, 0.4197620153, 0.6508329511, 
    0.3620707393, 0.4132447839, 0.3158825636, 0.2829504907, 0.1939029545, 0.3085561991, 
    0.4261417985, 0.3662804365, 0.3640728891, 0.2285072803, 0.2611197531, 0.3137708306, 
    0.1813996881, 0.2467649728, 0.3590491712, 0.2605759799, 0.2785786092, 0.2131326944, 
    0.4051060975, 0.2151563913, 0.3236663938, 0.2707078457, 0.1886326075, 0.1796456128, 
    0.1759846359, 0.2084640414, 0.2919830382, 0.3194782734, 0.2272844017, 0.1909537911, 
    0.1998754740, 0.3259357810, 0.2661243081, 0.2001659572, 0.3420787156, 0.2611944675, 
    0.2020030320, 0.1556288153, 0.2995066941, 0.1741548032, 0.1797898263, 0.1477390975, 
    0.1513507664, 0.1810729057, 0.1477674991, 0.2296603024
]

non_iid_rounds = list(range(1, len(non_iid_acc) + 1))

# ==========================================
# 50% PARTICIPATION PLOTS
# ==========================================

# --- 50% IID Plot (50 Rounds, Spacing: 5) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(iid_rounds, iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(iid_rounds, iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-IID (50% Participation) $\mu=0.2$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=50, step=5)
plt.tight_layout()
plt.show()

# --- 50% Non-IID Plot (100 Rounds, Spacing: 10) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(non_iid_rounds, non_iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(non_iid_rounds, non_iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-Non-IID (50% Participation) $\mu=0.2$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=100, step=10)
plt.tight_layout()
plt.show()

# %%
def style_plot(ax, max_rounds, step):
    ax.set_xticks(range(0, max_rounds + 1, step))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['bottom'].set_color('#CCCCCC')
    
    ax.grid(axis='y', color='#E0E0E0', linestyle='-')
    ax.grid(axis='x', visible=False)
    
    ax.tick_params(axis='both', which='both', length=0)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2, frameon=False)

# ==========================================
# DATA (30% Participation, mu=0.2)
# ==========================================

# IID Data (50 Rounds) [cite: 28, 29, 30]
iid_acc_30 = [
    0.8449000120, 0.9031999707, 0.9240000248, 0.9368000031, 0.9435999990, 0.9532999992, 
    0.9570000172, 0.9610000253, 0.9623000026, 0.9660999775, 0.9681000113, 0.9700000286, 
    0.9685999751, 0.9728999734, 0.9710000157, 0.9711999893, 0.9753999710, 0.9739999771, 
    0.8982999921, 0.9154000282, 0.8946999907, 0.8285999894, 0.8145999908, 0.8996000290, 
    0.8600999713, 0.9348999858, 0.8518999815, 0.8891000152
]

non_iid_loss_30 = [
    2.8041565418, 2.9975788593, 1.4627591372, 2.0087518692, 1.9256974459, 1.4089568853, 
    2.2789931297, 1.3035516739, 0.7904183865, 1.1623735428, 1.6385560036, 1.7027820349, 
    0.7829068899, 0.8784730434, 0.6894991398, 0.8199484348, 0.8132913113, 0.9507263899, 
    0.6302327514, 1.1139070988, 1.3282059431, 1.4123852253, 0.5722067356, 0.7629650831, 
    1.0833061934, 0.5317105055, 0.6975547075, 1.3368366957, 0.4559127092, 0.6719489098, 
    0.7190014720, 0.4933497608, 1.2969937325, 0.4129481316, 0.6361217499, 0.4933209121, 
    0.5949956775, 0.6161541939, 0.8628189564, 0.3785651028, 0.5353329182, 0.6145491004, 
    0.4953995049, 0.5984107256, 0.2866142690, 0.2278357595, 0.3315512836, 0.2536373436, 
    0.5519396067, 0.5182458758, 0.7985914350, 0.2200724185, 0.3915616572, 0.7499839067, 
    1.0455076694, 0.8455049992, 0.5031507015, 0.2466411591, 0.2633668482, 0.2259358168, 
    0.4530249536, 0.6195524335, 0.3799445927, 0.7863918543, 0.4853604138, 0.8238950968, 
    0.2325350791, 0.4169481099, 0.1979277134, 0.6910611987, 0.6459619999, 0.1781305820, 
    0.4126365781, 0.5682404041, 0.2184897959, 0.4775870740, 0.3035786450, 0.3914831877, 
    0.3485486209, 0.3082953691, 0.4683951735, 0.2587716281, 0.3940485716, 0.3721634150, 
    0.4596827030, 0.5799874663, 0.2486111075, 0.3005287945, 0.2564136088, 0.3112697005, 
    0.2756300569, 0.2542155087, 0.3092586696, 0.4989033341, 0.5789553523, 0.2812784910, 
    0.3952006400, 0.1846861392, 0.4010750055, 0.2896328866
]

non_iid_rounds_30 = list(range(1, len(non_iid_acc_30) + 1))

# ==========================================
# 30% PARTICIPATION PLOTS
# ==========================================

# --- 30% IID Plot (50 Rounds, Spacing: 5) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(iid_rounds_30, iid_acc_30, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(iid_rounds_30, iid_loss_30, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-IID (30% Participation) $\mu=0.2$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=50, step=5)
plt.tight_layout()
plt.show()

# --- 30% Non-IID Plot (100 Rounds, Spacing: 10) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(non_iid_rounds_30, non_iid_acc_30, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(non_iid_rounds_30, non_iid_loss_30, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-Non-IID (30% Participation) $\mu=0.2$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=100, step=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

def style_plot(ax, max_rounds, step):
    ax.set_xticks(range(0, max_rounds + 1, step))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['bottom'].set_color('#CCCCCC')
    
    ax.grid(axis='y', color='#E0E0E0', linestyle='-')
    ax.grid(axis='x', visible=False)
    
    ax.tick_params(axis='both', which='both', length=0)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2, frameon=False)

# ==========================================
# DATA (100% Participation, mu=0.5)
# ==========================================

# IID Data (20 Rounds)
iid_acc = [
    0.8300999999, 0.8905000091, 0.9122999907, 0.9239000082, 0.9325000048, 0.9402999878, 
    0.9453999996, 0.9501000047, 0.9538000226, 0.9567999840, 0.9599000216, 0.9635999799, 
    0.9653000236, 0.9671999812, 0.9689999819, 0.9702999592, 0.9714999795, 0.9721999764, 
    0.9722999930, 0.9738000035
]

iid_loss = [
    0.8721870184, 0.4307663143, 0.3208964467, 0.2679477930, 0.2337907255, 0.2081637681, 
    0.1880832762, 0.1715772152, 0.1585228592, 0.1469046324, 0.1369656920, 0.1285132617, 
    0.1212522984, 0.1150817871, 0.1095184311, 0.1048858464, 0.1002532616, 0.0963348076, 
    0.0930028856, 0.0899321437
]

iid_rounds = list(range(1, len(iid_acc) + 1))

# Non-IID Data (50 Rounds)
non_iid_acc = [
    0.3072000146, 0.4893000126, 0.5978000164, 0.6467999816, 0.6786000133, 0.7095000148, 
    0.7373999953, 0.7547000051, 0.7712000012, 0.7843999863, 0.7955999970, 0.8051000237, 
    0.8151999712, 0.8209000230, 0.8273000121, 0.8330000043, 0.8392999768, 0.8443999887, 
    0.8471999764, 0.8514000177, 0.8586000204, 0.8610000014, 0.8661000133, 0.8701000214, 
    0.8744000196, 0.8780000210, 0.8805000186, 0.8834000230, 0.8858000040, 0.8888999820, 
    0.8923000097, 0.8945999742, 0.8957999945, 0.8974000216, 0.8985000253, 0.8993999958, 
    0.9006999731, 0.9029999971, 0.9035999775, 0.9052000046, 0.9054999948, 0.9075999856, 
    0.9083999991, 0.9096000195, 0.9107999802, 0.9126999974, 0.9118999839, 0.9128999710, 
    0.9139999747, 0.9146000147
]

non_iid_loss = [
    2.0301625729, 1.6519523859, 1.3434619904, 1.1298452616, 0.9811748862, 0.8663812280, 
    0.7827470303, 0.7196146250, 0.6688625216, 0.6290027499, 0.5958507061, 0.5672057271, 
    0.5425804853, 0.5216968656, 0.5031819940, 0.4863103628, 0.4696131945, 0.4553309083, 
    0.4465715885, 0.4335438013, 0.4174424708, 0.4094195068, 0.3979416490, 0.3858500123, 
    0.3752554953, 0.3669839203, 0.3589238524, 0.3514509499, 0.3448614180, 0.3382393718, 
    0.3313700259, 0.3258819580, 0.3209855855, 0.3150940537, 0.3102121651, 0.3058268726, 
    0.3017456830, 0.2960731685, 0.2925474346, 0.2880699634, 0.2848200798, 0.2814800441, 
    0.2780487835, 0.2744434177, 0.2720112800, 0.2676671147, 0.2663262486, 0.2630473971, 
    0.2611141204, 0.2588814795
]

non_iid_rounds = list(range(1, len(non_iid_acc) + 1))

# ==========================================
# 100% PARTICIPATION PLOTS (mu = 0.5)
# ==========================================

# --- 100% IID Plot (20 Rounds, Spacing: 2) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(iid_rounds, iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(iid_rounds, iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-IID (100% Participation) $\mu=0.5$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=20, step=2)
plt.tight_layout()
plt.show()

# --- 100% Non-IID Plot (50 Rounds, Spacing: 5) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(non_iid_rounds, non_iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(non_iid_rounds, non_iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-Non-IID (100% Participation) $\mu=0.5$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=50, step=5)
plt.tight_layout()
plt.show()

# %%
def style_plot(ax, max_rounds, step):
    ax.set_xticks(range(0, max_rounds + 1, step))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['bottom'].set_color('#CCCCCC')
    
    ax.grid(axis='y', color='#E0E0E0', linestyle='-')
    ax.grid(axis='x', visible=False)
    
    ax.tick_params(axis='both', which='both', length=0)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2, frameon=False)

# ==========================================
# DATA (50% Participation, mu=0.5)
# ==========================================

# IID Data (50 Rounds)
iid_acc = [
    0.8015999794, 0.8701000214, 0.9041000009, 0.9179999828, 0.9314000010, 0.9376000166, 
    0.9431999922, 0.9426000118, 0.9535999894, 0.9571999907, 0.9600999951, 0.9614999890, 
    0.9648000002, 0.9664999843, 0.9693999887, 0.9696000218, 0.9707000256, 0.9717000127, 
    0.9735999703, 0.9728999734, 0.9743999839, 0.9750999808, 0.9749000072, 0.9753000140, 
    0.9758999944, 0.9768999815, 0.9774000049, 0.9775000215, 0.9782000184, 0.9790999889, 
    0.9782999754, 0.9792000055, 0.9789999723, 0.9803000093, 0.9799000025, 0.9807000160, 
    0.9804999828, 0.9803000093, 0.9810000062, 0.9810000062, 0.9812999964, 0.9819999933, 
    0.9818999767, 0.9814000130, 0.9824000001, 0.9825999737, 0.9826999903, 0.9832999706, 
    0.9842000008, 0.9828000069
]

iid_loss = [
    0.8599965572, 0.4731010199, 0.3457085490, 0.2910410762, 0.2368380427, 0.2150923163, 
    0.1906553060, 0.1873844266, 0.1608980298, 0.1463933289, 0.1365587413, 0.1315547973, 
    0.1208509803, 0.1157549918, 0.1084567904, 0.1071494371, 0.0987383127, 0.0950022116, 
    0.0928310826, 0.0918289125, 0.0863782689, 0.0834449157, 0.0820154697, 0.0802501738, 
    0.0786814690, 0.0754306912, 0.0722546205, 0.0733254105, 0.0693070143, 0.0693519488, 
    0.3224304318, 0.4832088947, 0.3601622283, 0.2338932604, 0.3722788692, 0.2788351178, 
    0.4002344310, 0.4785875380, 0.2735157311, 0.3212292790, 0.4954568744, 0.2372443378, 
    0.4321448207, 0.4085488915, 0.2351888865, 0.3405019939, 0.2939402461, 0.2235138118, 
    0.2561008036, 0.2533575296, 0.3725494742, 0.2050580531, 0.2157367468, 0.3652164936, 
    0.3886108696, 0.3893614113, 0.3821401298, 0.2563334107, 0.4734307230, 0.4876277447, 
    0.3041204214, 0.4339133799, 0.2546316683, 0.2693876326, 0.2801584601, 0.4796584547, 
    0.2195404470, 0.2851946950, 0.4752355516, 0.4904574156
]

non_iid_rounds = list(range(1, len(non_iid_acc) + 1))

# ==========================================
# 50% PARTICIPATION PLOTS (mu = 0.5)
# ==========================================

# --- 50% IID Plot (50 Rounds, Spacing: 5) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(iid_rounds, iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(iid_rounds, iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-IID (50% Participation) $\mu=0.5$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=50, step=5)
plt.tight_layout()
plt.show()

# --- 50% Non-IID Plot (100 Rounds, Spacing: 10) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(non_iid_rounds, non_iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(non_iid_rounds, non_iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance-Non-IID (50% Participation) $\mu=0.5$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=100, step=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

def style_plot(ax, max_rounds, step):
    ax.set_xticks(range(0, max_rounds + 1, step))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['bottom'].set_color('#CCCCCC')
    
    ax.grid(axis='y', color='#E0E0E0', linestyle='-')
    ax.grid(axis='x', visible=False)
    
    ax.tick_params(axis='both', which='both', length=0)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2, frameon=False)

# ==========================================
# DATA 
# ==========================================

# IID Data (50 Rounds)


iid_rounds = list(range(1, len(iid_acc) + 1))

# Non-IID Data (100 Rounds, 30% Participation)
non_iid_acc = [
    0.2315, 0.3234, 0.3250, 0.4734, 0.5041, 0.5168, 0.6052, 0.6426, 0.6727, 0.5851,
    0.5492, 0.7074, 0.5632, 0.5999, 0.7515, 0.6585, 0.7331, 0.7067, 0.7492, 0.7187,
    0.7277, 0.6690, 0.8472, 0.7679, 0.7537, 0.7279, 0.7924, 0.6941, 0.6933, 0.6459,
    0.6507, 0.8188, 0.7323, 0.7478, 0.8374, 0.8564, 0.7530, 0.7755, 0.8904, 0.8318,
    0.8486, 0.7427, 0.7302, 0.8424, 0.8293, 0.8301, 0.9171, 0.8049, 0.8685, 0.8683,
    0.9068, 0.7998, 0.8837, 0.9134, 0.8428, 0.8710, 0.9206, 0.8346, 0.8964, 0.8379,
    0.8758, 0.8344, 0.9195, 0.8361, 0.9140, 0.8054, 0.7499, 0.8003, 0.8856, 0.8709,
    0.9160, 0.7902, 0.9029, 0.9222, 0.8624, 0.9086, 0.9398, 0.9306, 0.9004, 0.7819,
    0.9273, 0.8038, 0.9272, 0.8384, 0.8385, 0.9221, 0.9287, 0.8549, 0.9130, 0.9252,
    0.9329, 0.9015, 0.9223, 0.8835, 0.9040, 0.8578, 0.8349, 0.8969, 0.9166, 0.9255
]

non_iid_loss = [
    2.2659, 2.2204, 2.3001, 1.8901, 1.7057, 1.6517, 1.5732, 1.2581, 1.2003, 1.1530,
    1.6557, 0.8641, 1.2593, 1.0806, 0.7116, 0.9981, 0.7479, 0.8081, 0.7412, 0.8158,
    0.6804, 0.8976, 0.4528, 0.6609, 0.7029, 0.7741, 0.6060, 1.0417, 0.9000, 1.1753,
    1.0357, 0.5237, 0.7097, 0.7071, 0.4677, 0.4403, 0.7086, 0.6113, 0.3233, 0.4864,
    0.4401, 0.7730, 0.9145, 0.4449, 0.5119, 0.5197, 0.2689, 0.5685, 0.3619, 0.3997,
    0.2727, 0.5491, 0.3418, 0.2623, 0.4476, 0.3725, 0.2401, 0.4852, 0.2959, 0.4672,
    0.3716, 0.4864, 0.2364, 0.4882, 0.2630, 0.5685, 0.7928, 0.6370, 0.3440, 0.3681,
    0.2445, 0.6443, 0.2733, 0.2438, 0.3929, 0.2612, 0.1803, 0.2072, 0.3099, 0.6800,
    0.2204, 0.5744, 0.2215, 0.4721, 0.4505, 0.2293, 0.2075, 0.4514, 0.2522, 0.2244,
    0.2103, 0.2927, 0.2365, 0.3454, 0.3076, 0.4436, 0.5342, 0.2882, 0.2257, 0.2217
]

non_iid_rounds = list(range(1, len(non_iid_acc) + 1))

# ==========================================
# PERFORMANCE PLOTS
# ==========================================

# --- IID Plot (50 Rounds, Spacing: 5) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(iid_rounds, iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(iid_rounds, iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance - IID (30% Participation) $\mu=0.5$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=50, step=5)
plt.tight_layout()
plt.show()

# --- Non-IID Plot (100 Rounds, Spacing: 10) ---
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(non_iid_rounds, non_iid_acc, color='#4472C4', label='Test Accuracy', linewidth=2)
ax.plot(non_iid_rounds, non_iid_loss, color='#ED7D31', label='Test Loss', linewidth=2)
ax.set_title(r"FedProx Global Performance - Non-IID( 30% Participation) $\mu=0.5$", pad=15, fontsize=12)
ax.set_xlabel("Communication Rounds")
ax.set_ylabel("Value")
style_plot(ax, max_rounds=100, step=10)
plt.tight_layout()
plt.show()
