# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define the specified .npy files
npy_files = ['iid_history1.npy', 'scaffold_iid_history1.npy']

# 2. Define your list of 2 losses (Replace these dummy values with your actual loss lists)
list_of_2_losses = [
    [0.5348038077, 0.3166976869, 0.2495007515, 0.2088758051, 0.1798899621, 0.1580309272, 0.1407034248, 0.1268360615, 0.1154449806, 0.1061868742, 0.0984557569, 0.0920683146, 0.0865588039, 0.0818089992, 0.0778674111, 0.0743337348, 0.0713631809, 0.0686866567, 0.0663236231, 0.0641557723],  # FedProx(0.2) dummy values
   [
    0.8721870184, 0.4307663143, 0.3208964467, 0.2679477930, 0.2337907255, 0.2081637681, 
    0.1880832762, 0.1715772152, 0.1585228592, 0.1469046324, 0.1369656920, 0.1285132617, 
    0.1212522984, 0.1150817871, 0.1095184311, 0.1048858464, 0.1002532616, 0.0963348076, 
    0.0930028856, 0.0899321437
]  # FedProx(0.5) dummy values
]

def load_loss_from_npy(filepath):
    """Safely unpacks a .npy file and extracts the loss array."""
    try:
        data = np.load(filepath, allow_pickle=True)
        
        # Case 1: 1D array of dictionaries (one per round)
        if isinstance(data, np.ndarray) and data.dtype == object and data.ndim > 0:
            losses = [epoch.get('loss') for epoch in data if isinstance(epoch, dict) and 'loss' in epoch]
            if losses:
                return losses

        # Case 2: 0-D array containing a single dictionary
        if isinstance(data, np.ndarray) and data.shape == ():
            data = data.item()
            
        # Case 3: Standard dictionary object
        if isinstance(data, dict):
            return list(data.get('loss', []))
            
        # Case 4: Direct numeric array/list of losses
        return list(data)
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return []

def main():
    # Define plot styles with distinct colors, lines, and markers for a clean, academic look
    plot_styles = {
        'FedAvg':       {'color': '#1f77b4', 'linestyle': '-',  'marker': None},
        'Scaffold':     {'color': '#2ca02c', 'linestyle': '--', 'marker': None},
        'FedProx(0.2)': {'color': '#d62728', 'linestyle': '-.', 'marker': None},
        'FedProx(0.5)': {'color': '#ff7f0e', 'linestyle': ':',  'marker': None}
    }
    
    plt.figure(figsize=(10, 6))

    # ---- 1. Plotting from .npy files ----
    # Mapping each specific file to its requested label
    npy_mappings = {
        'iid_history1.npy': 'FedAvg',
        'scaffold_iid_history1.npy': 'Scaffold'
    }

    for filepath in npy_files:
        label = npy_mappings.get(filepath)
        if not label:
            continue
            
        losses = load_loss_from_npy(filepath)
        if losses:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], marker=style['marker'], 
                     linewidth=2, markersize=6)
            print(f"Successfully loaded '{filepath}' -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")
        else:
            print(f"Warning: Could not read valid loss data from {filepath}")

    # ---- 2. Plotting from the standalone list ----
    # Mapping list indices to the requested labels
    list_mappings = {
        0: 'FedProx(0.2)',
        1: 'FedProx(0.5)'
    }

    for idx, losses in enumerate(list_of_2_losses):
        label = list_mappings.get(idx)
        if losses and label:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], marker=style['marker'], 
                     linewidth=2, markersize=6)
            print(f"Successfully loaded List Loss [{idx}] -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")

    # ---- Graph Styling ----
    plt.title("Training Loss Comparison", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("Communication Round", fontsize=14, labelpad=10)
    plt.ylabel("Training Loss", fontsize=14, labelpad=10)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    # Place legend with clear visual framing
    plt.legend(fontsize=12, loc='best', frameon=True)
    plt.tight_layout()
    
    # Save output graph
    output_name = "training_loss_comparison.png"
    plt.savefig(output_name, dpi=300)
    print("----------------------------------------------------------------------")
    print(f"Plot successfully saved as '{output_name}' at 300 DPI.")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Successfully loaded 'iid_history1.npy' -> Mapped to label: FedAvg     | Rounds: 20
# Successfully loaded 'scaffold_iid_history1.npy' -> Mapped to label: Scaffold   | Rounds: 20
# Successfully loaded List Loss [0] -> Mapped to label: FedProx(0.2) | Rounds: 20
# Successfully loaded List Loss [1] -> Mapped to label: FedProx(0.5) | Rounds: 20
# ----------------------------------------------------------------------
# Plot successfully saved as 'training_loss_comparison.png' at 300 DPI.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define the specified .npy files
npy_files = ['iid_history2.npy', 'scaffold_iid_history2.npy']

# 2. Define your list of 2 losses (Replace these dummy values with your actual loss lists)
list_of_2_losses = [
    [
    0.6020631790, 0.3440597057, 0.2711368501, 0.2270312756, 0.2088869214, 0.1755691916, 
    0.1480602473, 0.1389341503, 0.1279792786, 0.1159582362, 0.1100943610, 0.1037503779, 
    0.1061600819, 0.0959735885, 0.0920068771, 0.0883925557, 0.0810296610, 0.0812384039, 
    0.0757355839, 0.0766825378, 0.0695875436, 0.0762183964, 0.0669947118, 0.0631802976, 
    0.0649711415, 0.0613928400, 0.0633980855, 0.0624865852, 0.0581764206, 0.0605162121, 
    0.0572818182, 0.0559087582, 0.0529637337, 0.0571234301, 0.0563276410, 0.0526616760, 
    0.0515219048, 0.0572260357, 0.0487162992, 0.0483541042, 0.0538527481, 0.0511154681, 
    0.0485662036, 0.0506456569, 0.0471363440, 0.0467624404, 0.0475304238, 0.0476172753, 
    0.0491559207, 0.0444937795
],  # FedProx(0.2) dummy values
[
    0.8599965572, 0.4731010199, 0.3457085490, 0.2910410762, 0.2368380427, 0.2150923163, 
    0.1906553060, 0.1873844266, 0.1608980298, 0.1463933289, 0.1365587413, 0.1315547973, 
    0.1208509803, 0.1157549918, 0.1084567904, 0.1071494371, 0.0987383127, 0.0950022116, 
    0.0928310826, 0.0918289125, 0.0863782689, 0.0834449157, 0.0820154697, 0.0802501738, 
    0.0786814690, 0.0754306912, 0.0722546205, 0.0733254105, 0.0693070143, 0.0693519488, 
    0.0664891750, 0.0668270364, 0.0655001774, 0.0623244829, 0.0615055524, 0.0613218732, 
    0.0611978695, 0.0623562150, 0.0596605539, 0.0580383800, 0.0573665462, 0.0562702082, 
    0.0569809005, 0.0585713387, 0.0548933856, 0.0534752794, 0.0539706163, 0.0537062027, 
    0.0512567982, 0.0509988479
] # FedProx(0.5) dummy values
]

def load_loss_from_npy(filepath):
    """Safely unpacks a .npy file and extracts the loss array."""
    try:
        data = np.load(filepath, allow_pickle=True)
        
        # Case 1: 1D array of dictionaries (one per round)
        if isinstance(data, np.ndarray) and data.dtype == object and data.ndim > 0:
            losses = [epoch.get('loss') for epoch in data if isinstance(epoch, dict) and 'loss' in epoch]
            if losses:
                return losses

        # Case 2: 0-D array containing a single dictionary
        if isinstance(data, np.ndarray) and data.shape == ():
            data = data.item()
            
        # Case 3: Standard dictionary object
        if isinstance(data, dict):
            return list(data.get('loss', []))
            
        # Case 4: Direct numeric array/list of losses
        return list(data)
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return []

def main():
    # Define plot styles with distinct colors, lines, and markers for a clean, academic look
    plot_styles = {
        'FedAvg':       {'color': '#1f77b4', 'linestyle': '-',  'marker': None},
        'Scaffold':     {'color': '#2ca02c', 'linestyle': '--', 'marker': None},
        'FedProx(0.2)': {'color': '#d62728', 'linestyle': '-.', 'marker': None},
        'FedProx(0.5)': {'color': '#ff7f0e', 'linestyle': ':',  'marker': None}
    }
    
    plt.figure(figsize=(10, 6))

    # ---- 1. Plotting from .npy files ----
    # Mapping each specific file to its requested label
    npy_mappings = {
        'iid_history1.npy': 'FedAvg',
        'scaffold_iid_history1.npy': 'Scaffold'
    }

    for filepath in npy_files:
        label = npy_mappings.get(filepath)
        if not label:
            continue
            
        losses = load_loss_from_npy(filepath)
        if losses:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], marker=style['marker'], 
                     linewidth=2, markersize=6)
            print(f"Successfully loaded '{filepath}' -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")
        else:
            print(f"Warning: Could not read valid loss data from {filepath}")

    # ---- 2. Plotting from the standalone list ----
    # Mapping list indices to the requested labels
    list_mappings = {
        0: 'FedProx(0.2)',
        1: 'FedProx(0.5)'
    }

    for idx, losses in enumerate(list_of_2_losses):
        label = list_mappings.get(idx)
        if losses and label:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], marker=style['marker'], 
                     linewidth=2, markersize=6)
            print(f"Successfully loaded List Loss [{idx}] -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")

    # ---- Graph Styling ----
    plt.title("Training Loss Comparison", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("Communication Round", fontsize=14, labelpad=10)
    plt.ylabel("Training Loss", fontsize=14, labelpad=10)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    # Place legend with clear visual framing
    plt.legend(fontsize=12, loc='best', frameon=True)
    plt.tight_layout()
    
    # Save output graph
    output_name = "training_loss_comparison.png"
    plt.savefig(output_name, dpi=300)
    print("----------------------------------------------------------------------")
    print(f"Plot successfully saved as '{output_name}' at 300 DPI.")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Successfully loaded List Loss [0] -> Mapped to label: FedProx(0.2) | Rounds: 50
# Successfully loaded List Loss [1] -> Mapped to label: FedProx(0.5) | Rounds: 50
# ----------------------------------------------------------------------
# Plot successfully saved as 'training_loss_comparison.png' at 300 DPI.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define the specified .npy files
npy_files = ['iid_history2.npy', 'scaffold_iid_history2.npy']

# 2. Define your list of 2 losses
list_of_2_losses = [
    [
    0.6020631790, 0.3440597057, 0.2711368501, 0.2270312756, 0.2088869214, 0.1755691916, 
    0.1480602473, 0.1389341503, 0.1279792786, 0.1159582362, 0.1100943610, 0.1037503779, 
    0.1061600819, 0.0959735885, 0.0920068771, 0.0883925557, 0.0810296610, 0.0812384039, 
    0.0757355839, 0.0766825378, 0.0695875436, 0.0762183964, 0.0669947118, 0.0631802976, 
    0.0649711415, 0.0613928400, 0.0633980855, 0.0624865852, 0.0581764206, 0.0605162121, 
    0.0572818182, 0.0559087582, 0.0529637337, 0.0571234301, 0.0563276410, 0.0526616760, 
    0.0515219048, 0.0572260357, 0.0487162992, 0.0483541042, 0.0538527481, 0.0511154681, 
    0.0485662036, 0.0506456569, 0.0471363440, 0.0467624404, 0.0475304238, 0.0476172753, 
    0.0491559207, 0.0444937795
],  # FedProx(0.2)
   [
    0.8599965572, 0.4731010199, 0.3457085490, 0.2910410762, 0.2368380427, 0.2150923163, 
    0.1906553060, 0.1873844266, 0.1608980298, 0.1463933289, 0.1365587413, 0.1315547973, 
    0.1208509803, 0.1157549918, 0.1084567904, 0.1071494371, 0.0987383127, 0.0950022116, 
    0.0928310826, 0.0918289125, 0.0863782689, 0.0834449157, 0.0820154697, 0.0802501738, 
    0.0786814690, 0.0754306912, 0.0722546205, 0.0733254105, 0.0693070143, 0.0693519488, 
    0.0664891750, 0.0668270364, 0.0655001774, 0.0623244829, 0.0615055524, 0.0613218732, 
    0.0611978695, 0.0623562150, 0.0596605539, 0.0580383800, 0.0573665462, 0.0562702082, 
    0.0569809005, 0.0585713387, 0.0548933856, 0.0534752794, 0.0539706163, 0.0537062027, 
    0.0512567982, 0.0509988479
]  # FedProx(0.5)
]

def load_loss_from_npy(filepath):
    """Safely unpacks a .npy file and extracts the loss array."""
    try:
        data = np.load(filepath, allow_pickle=True)
        
        # Case 1: 1D array of dictionaries (one per round)
        if isinstance(data, np.ndarray) and data.dtype == object and data.ndim > 0:
            losses = [epoch.get('loss') for epoch in data if isinstance(epoch, dict) and 'loss' in epoch]
            if losses:
                return losses

        # Case 2: 0-D array containing a single dictionary
        if isinstance(data, np.ndarray) and data.shape == ():
            data = data.item()
            
        # Case 3: Standard dictionary object
        if isinstance(data, dict):
            return list(data.get('loss', []))
            
        # Case 4: Direct numeric array/list of losses
        return list(data)
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return []

def main():
    # Define plot styles with distinct colors, lines, and markers
    plot_styles = {
        'FedAvg':       {'color': '#1f77b4', 'linestyle': '-',  'marker': None},
        'Scaffold':     {'color': '#2ca02c', 'linestyle': '--', 'marker': None},
        'FedProx(0.2)': {'color': '#d62728', 'linestyle': '-.', 'marker': None},
        'FedProx(0.5)': {'color': '#ff7f0e', 'linestyle': ':',  'marker': None}
    }
    
    plt.figure(figsize=(10, 6))

    # ---- 1. Plotting from .npy files ----
    for filepath in npy_files:
        lowered_name = filepath.lower()
        
        # Flexible string matching avoids mismatch bugs if file versions change
        if 'scaffold' in lowered_name:
            label = 'Scaffold'
        elif 'iid' in lowered_name or 'fedavg' in lowered_name:
            label = 'FedAvg'
        else:
            continue
            
        losses = load_loss_from_npy(filepath)
        if losses:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], marker=style['marker'], 
                     linewidth=2)
            print(f"Successfully loaded '{filepath}' -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")
        else:
            print(f"Warning: Could not read valid loss data from {filepath}")

    # ---- 2. Plotting from the standalone list ----
    list_mappings = {
        0: 'FedProx(0.2)',
        1: 'FedProx(0.5)'
    }

    for idx, losses in enumerate(list_of_2_losses):
        label = list_mappings.get(idx)
        if losses and label:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], marker=style['marker'], 
                     linewidth=2)
            print(f"Successfully loaded List Loss [{idx}] -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")

    # ---- Graph Styling ----
    plt.title("Training Loss Comparison", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("Communication Round", fontsize=14, labelpad=10)
    plt.ylabel("Training Loss", fontsize=14, labelpad=10)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    plt.legend(fontsize=12, loc='best', frameon=True)
    plt.tight_layout()
    
    # Save output graph
    output_name = "training_loss_comparison.png"
    plt.savefig(output_name, dpi=300)
    print("----------------------------------------------------------------------")
    print(f"Plot successfully saved as '{output_name}' at 300 DPI.")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Successfully loaded 'iid_history2.npy' -> Mapped to label: FedAvg     | Rounds: 50
# Successfully loaded 'scaffold_iid_history2.npy' -> Mapped to label: Scaffold   | Rounds: 50
# Successfully loaded List Loss [0] -> Mapped to label: FedProx(0.2) | Rounds: 50
# Successfully loaded List Loss [1] -> Mapped to label: FedProx(0.5) | Rounds: 50
# ----------------------------------------------------------------------
# Plot successfully saved as 'training_loss_comparison.png' at 300 DPI.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Updated file list to version 3
npy_files = ['iid_history3.npy', 'scaffold_iid_history3.npy']

# 2. Standalone list of 2 losses (FedProx data)
list_of_2_losses = [
  [
    0.6082218885, 0.3425852060, 0.2601391673, 0.2240740061, 0.1906364858, 0.1656354070, 
    0.1476243883, 0.1305091828, 0.1308698654, 0.1158463359, 0.1067756191, 0.1026732549, 
    0.1026836932, 0.0882179886, 0.1005802676, 0.0956401303, 0.0837820843, 0.0832754597, 
    0.0785145685, 0.0764932930, 0.0713589936, 0.0703732222, 0.0663917735, 0.0671049282, 
    0.0664941519, 0.0636906996, 0.0673578456, 0.0624839291, 0.0600167103, 0.0628929213, 
    0.0560389236, 0.0621517412, 0.0563486032, 0.0586927198, 0.0573477671, 0.0591009222, 
    0.0517253466, 0.0528412126, 0.0552792922, 0.0543686636, 0.0485789925, 0.0471824519, 
    0.0477585793, 0.0473194793, 0.0491026118, 0.0458566137, 0.0468972847, 0.0473047160, 
    0.0465059467, 0.0466734245
],  # FedProx(0.2)
    [
    0.8529, 0.4562, 0.3481, 0.3102, 0.2573, 0.2378, 0.2127, 0.2147, 0.1895, 0.1645,
    0.1968, 0.1656, 0.1355, 0.1397, 0.1220, 0.1203, 0.1165, 0.1110, 0.1063, 0.0999,
    0.1044, 0.1000, 0.0916, 0.0933, 0.0819, 0.0878, 0.0813, 0.0771, 0.0820, 0.0803,
    0.0786, 0.0730, 0.0743, 0.0723, 0.0741, 0.0738, 0.0704, 0.0672, 0.0663, 0.0633,
    0.0636, 0.0644, 0.0626, 0.0644, 0.0616, 0.0629, 0.0647, 0.0636, 0.0578, 0.0574
]   # FedProx(0.5)
]

def load_loss_from_npy(filepath):
    """Safely unpacks a .npy file and extracts the loss array."""
    try:
        data = np.load(filepath, allow_pickle=True)
        
        # Case 1: 1D array of dictionaries (one per round)
        if isinstance(data, np.ndarray) and data.dtype == object and data.ndim > 0:
            losses = [epoch.get('loss') for epoch in data if isinstance(epoch, dict) and 'loss' in epoch]
            if losses:
                return losses

        # Case 2: 0-D array containing a single dictionary
        if isinstance(data, np.ndarray) and data.shape == ():
            data = data.item()
            
        # Case 3: Standard dictionary object
        if isinstance(data, dict):
            return list(data.get('loss', []))
            
        # Case 4: Direct numeric array/list of losses
        return list(data)
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return []

def main():
    # HIGH-CONTRAST DARK PALETTE + DISTINCT LINESTYLES
    # Added alpha transparency and slightly thicker lines to make overlaps readable
    plot_styles = {
        'FedAvg':       {'color': '#1f77b4', 'linestyle': '-',  'linewidth': 2.5}, # Midnight Navy
        'Scaffold':     {'color': '#2ca02c', 'linestyle': '--', 'linewidth': 2.2}, # Crimson Wine
        'FedProx(0.2)': {'color': '#d62728', 'linestyle': '-.', 'linewidth': 2.2}, # Forest Green
        'FedProx(0.5)': {'color': '#ff7f0e', 'linestyle': ':',  'linewidth': 2.5}  # Dark Amber
    }
    
    plt.figure(figsize=(10, 6))

    # ---- 1. Plotting from updated .npy files ----
    for filepath in npy_files:
        lowered_name = filepath.lower()
        
        # Flexible substring validation prevents matching bugs across versions
        if 'scaffold' in lowered_name:
            label = 'Scaffold'
        elif 'iid' in lowered_name or 'fedavg' in lowered_name:
            label = 'FedAvg'
        else:
            continue
            
        losses = load_loss_from_npy(filepath)
        if losses:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], linewidth=style['linewidth'],
                     alpha=0.85, zorder=3 if label=='FedAvg' else 2) 
            print(f"Successfully loaded '{filepath}' -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")
        else:
            print(f"Warning: Could not read valid loss data from {filepath}")

    # ---- 2. Plotting from the standalone list ----
    list_mappings = {
        0: 'FedProx(0.2)',
        1: 'FedProx(0.5)'
    }

    for idx, losses in enumerate(list_of_2_losses):
        label = list_mappings.get(idx)
        if losses and label:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], linewidth=style['linewidth'],
                     alpha=0.85, zorder=2)
            print(f"Successfully loaded List Loss [{idx}] -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")

    # ---- Graph Styling ----
    plt.title("Training Loss Comparison", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("Communication Round", fontsize=14, labelpad=10)
    plt.ylabel("Training Loss", fontsize=14, labelpad=10)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    plt.legend(fontsize=12, loc='best', frameon=True)
    plt.tight_layout()
    
    # Save output graph
    output_name = "training_loss_comparison.png"
    plt.savefig(output_name, dpi=300)
    print("----------------------------------------------------------------------")
    print(f"Plot successfully saved as '{output_name}' at 300 DPI.")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Successfully loaded 'iid_history3.npy' -> Mapped to label: FedAvg     | Rounds: 50
# Successfully loaded 'scaffold_iid_history3.npy' -> Mapped to label: Scaffold   | Rounds: 50
# Successfully loaded List Loss [0] -> Mapped to label: FedProx(0.2) | Rounds: 50
# Successfully loaded List Loss [1] -> Mapped to label: FedProx(0.5) | Rounds: 50
# ----------------------------------------------------------------------
# Plot successfully saved as 'training_loss_comparison.png' at 300 DPI.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Updated file list to the Non-IID history files
npy_files = ['non_iid_history1.npy', 'scaaffold_non_iid_history1.npy']

# 2. Standalone list of 2 losses (FedProx data)
list_of_2_losses = [
     [2.0616993904, 1.5750088692, 1.2423703671, 1.0278004408, 0.8707041144, 0.7536744475, 0.6656271219, 0.5985773206, 0.5485447049, 0.5089980364, 0.4773024023, 0.4479187131, 0.4258404374, 0.4064290524, 0.3897058964, 0.3745402098, 0.3624267876, 0.3512571156, 0.3415727317, 0.3321202397, 0.3156007826, 0.3081434369, 0.3008608520, 0.2944563925, 0.2888498902, 0.2833929956, 0.2772725523, 0.2724186182, 0.2671048641, 0.2624594569, 0.2586889565, 0.2542927861, 0.2507443726, 0.2474291026, 0.2416781783, 0.2383772284, 0.2354760468, 0.2326240689, 0.2302247137, 0.2275565416, 0.2248865515, 0.2220987529, 0.2198631763, 0.2178714424, 0.2150854468, 0.2133207023, 0.2114959955, 0.2114959955, 0.2114959955, 0.2095416188],  # FedProx(0.2)
     [
        2.0301625729, 1.6519523859, 1.3434619904, 1.1298452616, 0.9811748862, 0.8663812280, 
        0.7827470303, 0.7196146250, 0.6688625216, 0.6290027499, 0.5958507061, 0.5672057271, 
        0.5425804853, 0.5216968656, 0.5031819940, 0.4863103628, 0.4696131945, 0.4553309083, 
        0.4465715885, 0.4335438013, 0.4174424708, 0.4094195068, 0.3979416490, 0.3858500123, 
        0.3752554953, 0.3669839203, 0.3589238524, 0.3514509499, 0.3448614180, 0.3382393718, 
        0.3313700259, 0.3258819580, 0.3209855855, 0.3150940537, 0.3102121651, 0.3058268726, 
        0.3017456830, 0.2960731685, 0.2925474346, 0.2880699634, 0.2848200798, 0.2814800441, 
        0.2780487835, 0.2744434177, 0.2720112800, 0.2676671147, 0.2663262486, 0.2630473971, 
        0.2611141204, 0.2588814795
    ]  # FedProx(0.5)
]

def load_loss_from_npy(filepath):
    """Safely unpacks a .npy file and extracts the loss array."""
    try:
        data = np.load(filepath, allow_pickle=True)
        
        # Case 1: 1D array of dictionaries (one per round)
        if isinstance(data, np.ndarray) and data.dtype == object and data.ndim > 0:
            losses = [epoch.get('loss') for epoch in data if isinstance(epoch, dict) and 'loss' in epoch]
            if losses:
                return losses

        # Case 2: 0-D array containing a single dictionary
        if isinstance(data, np.ndarray) and data.shape == ():
            data = data.item()
            
        # Case 3: Standard dictionary object
        if isinstance(data, dict):
            return list(data.get('loss', []))
            
        # Case 4: Direct numeric array/list of losses
        return list(data)
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return []

def main():
    # RESTORED DEEP CONTRAST DARK PALETTE FOR HIGH VISIBILITY
    plot_styles = {
        'FedAvg':       {'color': '#1f77b4', 'linestyle': '-',  'linewidth': 2.5}, # Midnight Navy
        'Scaffold':     {'color': '#2ca02c', 'linestyle': '--', 'linewidth': 2.2}, # Crimson Wine
        'FedProx(0.2)': {'color': '#d62728', 'linestyle': '-.', 'linewidth': 2.2}, # Forest Green
        'FedProx(0.5)': {'color': '#ff7f0e', 'linestyle': ':',  'linewidth': 2.5}  # Dark Amber
    }
    
    plt.figure(figsize=(10, 6))

    # ---- 1. Plotting from updated .npy files ----
    for filepath in npy_files:
        lowered_name = filepath.lower()
        
        # FIXED: Added 'scaa' string check to cleanly catch the double-a filename typo
        if 'scaff' in lowered_name or 'scaa' in lowered_name:
            label = 'Scaffold'
        elif 'iid' in lowered_name or 'fedavg' in lowered_name:
            label = 'FedAvg'
        else:
            continue
            
        losses = load_loss_from_npy(filepath)
        if losses:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            # Applied alpha blending and layer controls (zorder) for overlaps
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], linewidth=style['linewidth'],
                     alpha=0.85, zorder=3 if label=='FedAvg' else 2) 
            print(f"Successfully loaded '{filepath}' -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")
        else:
            print(f"Warning: Could not read valid loss data from {filepath}")

    # ---- 2. Plotting from the standalone list ----
    list_mappings = {
        0: 'FedProx(0.2)',
        1: 'FedProx(0.5)'
    }

    for idx, losses in enumerate(list_of_2_losses):
        label = list_mappings.get(idx)
        if losses and label:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], linewidth=style['linewidth'],
                     alpha=0.85, zorder=2)
            print(f"Successfully loaded List Loss [{idx}] -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")

    # ---- Graph Styling ----
    plt.title("Training Loss Comparison (Non-IID)", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("Communication Round", fontsize=14, labelpad=10)
    plt.ylabel("Training Loss", fontsize=14, labelpad=10)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    plt.legend(fontsize=12, loc='best', frameon=True)
    plt.tight_layout()
    
    # Save output graph
    output_name = "non_iid_training_loss_comparison.png"
    plt.savefig(output_name, dpi=300)
    print("----------------------------------------------------------------------")
    print(f"Plot successfully saved as '{output_name}' at 300 DPI.")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Successfully loaded 'non_iid_history1.npy' -> Mapped to label: FedAvg     | Rounds: 50
# Successfully loaded 'scaaffold_non_iid_history1.npy' -> Mapped to label: Scaffold   | Rounds: 50
# Successfully loaded List Loss [0] -> Mapped to label: FedProx(0.2) | Rounds: 50
# Successfully loaded List Loss [1] -> Mapped to label: FedProx(0.5) | Rounds: 50
# ----------------------------------------------------------------------
# Plot successfully saved as 'non_iid_training_loss_comparison.png' at 300 DPI.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define your 4 lists of losses here
list_of_4_losses = [
    # Index 0: FedAvg
    
       [
    2.72004771232605, 2.9320385456085205, 1.577375054359436, 2.173856258392334, 1.4900836944580078,
    0.9627352356910706, 0.890572726726532, 1.1792317628860474, 1.179039716720581, 1.0166486501693726,
    0.9434992074966431, 0.7634389400482178, 0.9524283409118652, 0.9331791996955872, 0.920488178730011,
    0.5639874339103699, 0.5203378200531006, 0.4576597511768341, 0.5729007720947266, 0.7219682931900024,
    0.7314764857292175, 0.6520023345947266, 0.38430747389793396, 0.3239150643348694, 0.3323439955711365,
    0.5424506664276123, 0.34696900844573975, 0.296423077583313, 0.48773592710494995, 0.3670912981033325,
    0.36217206716537476, 0.277511864900589, 0.3290049135684967, 0.21489489078521729, 0.7377806305885315,
    0.30256977677345276, 0.25556644797325134, 0.29479649662971497, 0.5503512024879456, 0.4076900780200958,
    0.4497784674167633, 0.26976698637008667, 0.2292945384979248, 0.2009376436471939, 0.23288258910179138,
    0.3535277247428894, 0.3607568144798279, 0.18586920201778412, 0.5913573503494263, 0.35635319352149963,
    0.21911995112895966, 0.3092735707759857, 0.17679661512374878, 0.15300728380680084, 0.2940877377986908,
    0.30074912309646606, 0.22702233493328094, 0.28733551502227783, 0.22578147053718567, 0.16239520907402039,
    0.18939454853534698, 0.4464101195335388, 0.37601348757743835, 0.24437402188777924, 0.19295856356620789,
    0.27431702613830566, 0.2902335226535797, 0.19909672439098358, 0.1569085568189621, 0.543139636516571,
    0.43114325404167175, 0.2037404477596283, 0.15266236662864685, 0.2289910465478897, 0.14813275635242462,
    0.203270822763443, 0.2310332953929901, 0.22443923354148865, 0.25988754630088806, 0.4899013042449951,
    0.3079697787761688, 0.1436629742383957, 0.14213669300079346, 0.2160089910030365, 0.19391094148159027,
    0.16596657037734985, 0.19567082822322845, 0.28161415457725525, 0.2844843864440918, 0.17814646661281586,
    0.2940143048763275, 0.20333270728588104, 0.32642999291419983, 0.1354624181985855, 0.180526003241539,
    0.13074229657649994, 0.14495305716991425, 0.20582541823387146, 0.17404039204120636, 0.1694549322128296

    ],  
    
    # Index 1: Scaffold
   [
    2.9813616275787354, 2.241809844970703, 0.8954888582229614, 0.6359702348709106, 0.6553802490234375,
    0.4291457533836365, 0.3958699107170105, 0.35095465183258057, 0.35387033224105835, 0.30595099925994873,
    0.2667222023010254, 0.2814355194568634, 0.2495725303888321, 0.34705430269241333, 0.21795769035816193,
    0.260047972202301, 0.23256494104862213, 0.19161316752433777, 0.18822211027145386, 0.2237100899219513,
    0.225098118185997, 0.17203979194164276, 0.18135027587413788, 0.19310486316680908, 0.18549543619155884,
    0.23361702263355255, 0.18773546814918518, 0.20392902195453644, 0.1582455337047577, 0.13456669449806213,
    0.16602157056331635, 0.1863337755203247, 0.2058698534965515, 0.21862053871154785, 0.16259552538394928,
    0.16693292558193207, 0.16985398530960083, 0.1688772439956665, 0.15537148714065552, 0.1494978815317154,
    0.13529732823371887, 0.15809904038906097, 0.12638278305530548, 0.13146740198135376, 0.1863245666027069,
    0.178753063082695, 0.13705745339393616, 0.15045323967933655, 0.20548562705516815, 0.13448958098888397,
    0.12786239385604858, 0.1392400711774826, 0.13854975998401642, 0.13000357151031494, 0.13257922232151031,
    0.13965025544166565, 0.13170970976352692, 0.15789103507995605, 0.10579188168048859, 0.13890720903873444,
    0.11966558545827866, 0.10798478871583939, 0.12024804949760437, 0.10546333342790604, 0.1043560579419136,
    0.11128873378038406, 0.11861446499824524, 0.11963607370853424, 0.18452869355678558, 0.11604043841362,
    0.09534110873937607, 0.10452253371477127, 0.14931796491146088, 0.13503102958202362, 0.14362376928329468,
    0.11591776460409164, 0.10907518118619919, 0.11580810695886612, 0.09853999316692352, 0.13485248386859894,
    0.1452181190252304, 0.1156357079744339, 0.12028765678405762, 0.13176080584526062, 0.108660988509655,
    0.1273912638425827, 0.11711051315069199, 0.1386527419090271, 0.13042570650577545, 0.1327884942293167,
    0.11886961758136749, 0.13215257227420807, 0.12068545073270798, 0.09358706325292587, 0.10553702712059021,
    0.0945633202791214, 0.1048830896615982, 0.09487179666757584, 0.0841178148984909, 0.0970604345202446
],  
    
    # Index 2: FedProx(0.2) - Your provided actual values
    [
    2.0412251949, 1.8308022022, 1.4512133598, 1.2053847313, 1.2773630619, 1.1907887459, 
    1.3053778410, 0.8541061282, 0.9006500244, 0.7781010270, 0.6843004227, 0.6271806955, 
    0.5820704103, 0.4862810075, 0.5818223357, 0.5681827664, 0.7680131793, 0.5299463272, 
    0.5692000000, 0.6905074716, 0.5719977021, 0.4280006886, 0.6284413338, 0.4043532610, 
    0.3039453030, 0.3218288124, 0.3672831059, 0.6028901339, 0.3545146585, 0.4330590367, 
    0.3601009548, 0.4818826616, 0.5800410509, 0.2900874913, 0.3911250234, 0.5323048830, 
    0.3338535428, 0.6146612763, 0.9826736450, 0.3255046606, 0.4117321670, 0.2751022577, 
    0.2512637675, 0.2763512433, 0.2094430476, 0.4173077047, 0.2662958801, 0.5052291751, 
    0.4726116359, 0.2925971448, 0.4685558081, 0.4039778113, 0.4197620153, 0.6508329511, 
    0.3620707393, 0.4132447839, 0.3158825636, 0.2829504907, 0.1939029545, 0.3085561991, 
    0.4261417985, 0.3662804365, 0.3640728891, 0.2285072803, 0.2611197531, 0.3137708306, 
    0.1813996881, 0.2467649728, 0.3590491712, 0.2605759799, 0.2785786092, 0.2131326944, 
    0.4051060975, 0.2151563913, 0.3236663938, 0.2707078457, 0.1886326075, 0.1796456128, 
    0.1759846359, 0.2084640414, 0.2919830382, 0.3194782734, 0.2272844017, 0.1909537911, 
    0.1998754740, 0.3259357810, 0.2661243081, 0.2001659572, 0.3420787156, 0.2611944675, 
    0.2020030320, 0.1556288153, 0.2995066941, 0.1741548032, 0.1797898263, 0.1477390975, 
    0.1513507664, 0.1810729057, 0.1477674991, 0.2296603024
],  
    
    # Index 3: FedProx(0.5) - Your provided actual values
     [
    2.1968557835, 1.8826556206, 1.8511812687, 1.4492098093, 1.3547056913, 1.1188091040, 
    0.8149264455, 1.2483860254, 1.1796423197, 1.0668654442, 1.0910766125, 0.9522989988, 
    0.6678833961, 0.9914426804, 1.1926887035, 0.9899050593, 0.8032162786, 0.5341597199, 
    0.4977442324, 0.6929863095, 1.0383871794, 0.4778852165, 0.6093183160, 0.6265693307, 
    0.4503995180, 0.6334843636, 0.4959307611, 0.5672600269, 0.7256917953, 0.4400878847, 
    0.4679523408, 0.3530735075, 0.5447797179, 0.3958913684, 0.3848376870, 0.6121609211, 
    0.3801494241, 0.3490238488, 0.4112633169, 0.4457646012, 0.2876892388, 0.3955225945, 
    0.4721372128, 0.5630452633, 0.3202939928, 0.3952481449, 0.5244498849, 0.3803529143, 
    0.3873071373, 0.2914611697, 0.3480576575, 0.3388706744, 0.5976797938, 0.6093786359, 
    0.5034865737, 0.3914496899, 0.5416097641, 0.3313089609, 0.4426965714, 0.2670990229, 
    0.3224304318, 0.4832088947, 0.3601622283, 0.2338932604, 0.3722788692, 0.2788351178, 
    0.4002344310, 0.4785875380, 0.2735157311, 0.3212292790, 0.4954568744, 0.2372443378, 
    0.4321448207, 0.4085488915, 0.2351888865, 0.3405019939, 0.2939402461, 0.2235138118, 
    0.2561008036, 0.2533575296, 0.3725494742, 0.2050580531, 0.2157367468, 0.3652164936, 
    0.3886108696, 0.3893614113, 0.3821401298, 0.2563334107, 0.4734307230, 0.4876277447, 
    0.3041204214, 0.4339133799, 0.2546316683, 0.2693876326, 0.2801584601, 0.4796584547, 
    0.2195404470, 0.2851946950, 0.4752355516, 0.4904574156
]
]

def main():
    # DEEP CONTRAST DARK PALETTE FOR HIGH VISIBILITY OVERLAPS
    plot_styles = {
        'FedAvg':       {'color': '#1f77b4', 'linestyle': '-',  'linewidth': 2.5}, # Midnight Navy
        'Scaffold':     {'color': '#2ca02c', 'linestyle': '--', 'linewidth': 2.2}, # Crimson Wine
        'FedProx(0.2)': {'color': '#d62728', 'linestyle': '-.', 'linewidth': 2.2}, # Forest Green
        'FedProx(0.5)': {'color': '#ff7f0e', 'linestyle': ':',  'linewidth': 2.5}  # Dark Amber
    }
    
    # Map array index to the specific labels
    index_mappings = {
        0: 'FedAvg',
        1: 'Scaffold',
        2: 'FedProx(0.2)',
        3: 'FedProx(0.5)'
    }
    
    plt.figure(figsize=(10, 6))

    # Single unified loop to process and plot all 4 loss lists
    for idx, losses in enumerate(list_of_4_losses):
        label = index_mappings.get(idx)
        
        if losses and label:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            # Using alpha transparency and controlling layer ordering (zorder) for crisp overlaps
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], linewidth=style['linewidth'],
                     alpha=0.85, zorder=3 if label=='FedAvg' else 2)
            print(f"Successfully processed Index [{idx}] -> Mapped to label: {label:<12} | Rounds: {len(rounds)}")

    # ---- Graph Styling ----
    plt.title("Training Loss Comparison", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("Communication Round", fontsize=14, labelpad=10)
    plt.ylabel("Training Loss", fontsize=14, labelpad=10)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    plt.legend(fontsize=12, loc='best', frameon=True)
    plt.tight_layout()
    
    # Save output graph
    output_name = "training_loss_comparison.png"
    plt.savefig(output_name, dpi=300)
    print("----------------------------------------------------------------------")
    print(f"Plot successfully saved as '{output_name}' at 300 DPI.")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Successfully processed Index [0] -> Mapped to label: FedAvg       | Rounds: 100
# Successfully processed Index [1] -> Mapped to label: Scaffold     | Rounds: 100
# Successfully processed Index [2] -> Mapped to label: FedProx(0.2) | Rounds: 100
# Successfully processed Index [3] -> Mapped to label: FedProx(0.5) | Rounds: 100
# ----------------------------------------------------------------------
# Plot successfully saved as 'training_loss_comparison.png' at 300 DPI.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Updated file list to the Non-IID history files (Version 3)
npy_files = ['non_iid_history3.npy', 'scaffold_non_iid_history3.npy']

# 2. Standalone list of 2 losses (FedProx Non-IID data)
list_of_2_losses = [
    # FedProx(0.2)
   [
    2.8041565418, 2.9975788593, 1.4627591372, 2.0087518692, 1.9256974459, 1.4089568853, 
    2.2789931297, 1.3035516739, 0.7904183865, 1.1623735428, 1.6385560036, 1.7027820349, 
    0.7829068899, 0.8784730434, 0.6894991398, 0.8199484348, 0.8132913113, 0.9507263899, 
    0.6302327514, 1.1139070988, 1.3282059431, 1.4123852253, 0.5722067356, 0.7629650831, 
    1.0833061934, 0.5317105055, 0.6975547075, 1.3368366957, 0.4559127092, 0.6719489098, 
    0.7190014720, 0.4933497608, 1.2969937325, 0.4129481316, 0.6361217499, 0.4933209121, 
    0.5949956775, 0.6161541939, 0.8628189564, 0.3785651028, 0.5353329182, 0.6145491004, 
    0.4953995049, 0.5984107256, 0.2866142690, 0.2278357595, 0.3315512836, 0.2536373436, 
    0.5519396067, 0.5182458758, 0.7985914350, 0.2200724185, 0.3915616572, 0.7499839067, 
    1.0455076694, 0.8455049992, 0.5031507015, 0.2466411591, 0.2633668482, 0.2259358168, 
    0.4530249536, 0.6195524335, 0.3799445927, 0.7863918543, 0.4853604138, 0.8238950968, 
    0.2325350791, 0.4169481099, 0.1979277134, 0.6910611987, 0.6459619999, 0.1781305820, 
    0.4126365781, 0.5682404041, 0.2184897959, 0.4775870740, 0.3035786450, 0.3914831877, 
    0.3485486209, 0.3082953691, 0.4683951735, 0.2587716281, 0.3940485716, 0.3721634150, 
    0.4596827030, 0.5799874663, 0.2486111075, 0.3005287945, 0.2564136088, 0.3112697005, 
    0.2756300569, 0.2542155087, 0.3092586696, 0.4989033341, 0.5789553523, 0.2812784910, 
    0.3952006400, 0.1846861392, 0.4010750055, 0.2896328866
]
,  
    # FedProx(0.5)
   [
    2.2659, 2.2204, 2.3001, 1.8901, 1.7057, 1.6517, 1.5732, 1.2581, 1.2003, 1.1530,
    1.6557, 0.8641, 1.2593, 1.0806, 0.7116, 0.9981, 0.7479, 0.8081, 0.7412, 0.8158,
    0.6804, 0.8976, 0.4528, 0.6609, 0.7029, 0.7741, 0.6060, 1.0417, 0.9000, 1.1753,
    1.0357, 0.5237, 0.7097, 0.7071, 0.4677, 0.4403, 0.7086, 0.6113, 0.3233, 0.4864,
    0.4401, 0.7730, 0.9145, 0.4449, 0.5119, 0.5197, 0.2689, 0.5685, 0.3619, 0.3997,
    0.2727, 0.5491, 0.3418, 0.2623, 0.4476, 0.3725, 0.2401, 0.4852, 0.2959, 0.4672,
    0.3716, 0.4864, 0.2364, 0.4882, 0.2630, 0.5685, 0.7928, 0.6370, 0.3440, 0.3681,
    0.2445, 0.6443, 0.2733, 0.2438, 0.3929, 0.2612, 0.1803, 0.2072, 0.3099, 0.6800,
    0.2204, 0.5744, 0.2215, 0.4721, 0.4505, 0.2293, 0.2075, 0.4514, 0.2522, 0.2244,
    0.2103, 0.2927, 0.2365, 0.3454, 0.3076, 0.4436, 0.5342, 0.2882, 0.2257, 0.2217
]
]

def load_loss_from_npy(filepath):
    """Safely unpacks a .npy file and extracts the loss array."""
    try:
        data = np.load(filepath, allow_pickle=True)
        
        # Case 1: 1D array of dictionaries (one per round)
        if isinstance(data, np.ndarray) and data.dtype == object and data.ndim > 0:
            losses = [epoch.get('loss') for epoch in data if isinstance(epoch, dict) and 'loss' in epoch]
            if losses:
                return losses

        # Case 2: 0-D array containing a single dictionary
        if isinstance(data, np.ndarray) and data.shape == ():
            data = data.item()
            
        # Case 3: Standard dictionary object
        if isinstance(data, dict):
            return list(data.get('loss', []))
            
        # Case 4: Direct numeric array/list of losses
        return list(data)
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return []

def main():
    # Style configurations matching image_a261e7.png colors and styles
    plot_styles = {
        'FedAvg':       {'color': '#1f77b4', 'linestyle': '-',  'linewidth': 2.5}, # Blue, Solid
        'Scaffold':     {'color': '#2ca02c', 'linestyle': '--', 'linewidth': 2.2}, # Green, Dashed
        'FedProx(0.2)': {'color': '#d62728', 'linestyle': '-.', 'linewidth': 2.2}, # Red, Dash-Dot
        'FedProx(0.5)': {'color': '#ff7f0e', 'linestyle': ':',  'linewidth': 2.5}  # Orange, Dotted
    }
    
    plt.figure(figsize=(10, 6))

    # ---- 1. Plotting from updated .npy files ----
    for filepath in npy_files:
        lowered_name = filepath.lower()
        
        # Safe string containment handling
        if 'scaffold' in lowered_name or 'scaff' in lowered_name:
            label = 'Scaffold'
        elif 'iid' in lowered_name or 'fedavg' in lowered_name:
            label = 'FedAvg'
        else:
            continue
            
        losses = load_loss_from_npy(filepath)
        if losses:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], linewidth=style['linewidth'],
                     alpha=0.9, zorder=3 if label=='FedAvg' else 2) 
            print(f"Successfully loaded '{filepath}' -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")
        else:
            print(f"Warning: Could not read valid loss data from {filepath}")

    # ---- 2. Plotting from the standalone lists ----
    list_mappings = {
        0: 'FedProx(0.2)',
        1: 'FedProx(0.5)'
    }

    for idx, losses in enumerate(list_of_2_losses):
        label = list_mappings.get(idx)
        if losses and label:
            rounds = list(range(1, len(losses) + 1))
            style = plot_styles[label]
            
            plt.plot(rounds, losses, label=label, color=style['color'],
                     linestyle=style['linestyle'], linewidth=style['linewidth'],
                     alpha=0.9, zorder=2)
            print(f"Successfully loaded List Loss [{idx}] -> Mapped to label: {label:<10} | Rounds: {len(rounds)}")

    # ---- Graph Styling ----
    plt.title("Training Loss Comparison (Non-IID)", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("Communication Round", fontsize=14, labelpad=10)
    plt.ylabel("Training Loss", fontsize=14, labelpad=10)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    plt.legend(fontsize=12, loc='best', frameon=True)
    plt.tight_layout()
    
    # Save output graph
    output_name = "non_iid_training_loss_comparison.png"
    plt.savefig(output_name, dpi=300)
    print("----------------------------------------------------------------------")
    print(f"Plot successfully saved as '{output_name}' at 300 DPI.")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Successfully loaded 'non_iid_history3.npy' -> Mapped to label: FedAvg     | Rounds: 100
# Successfully loaded 'scaffold_non_iid_history3.npy' -> Mapped to label: Scaffold   | Rounds: 100
# Successfully loaded List Loss [0] -> Mapped to label: FedProx(0.2) | Rounds: 100
# Successfully loaded List Loss [1] -> Mapped to label: FedProx(0.5) | Rounds: 100
# ----------------------------------------------------------------------
# Plot successfully saved as 'non_iid_training_loss_comparison.png' at 300 DPI.
