# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD
from concurrent.futures import ThreadPoolExecutor

# %%
# 1. Thread Configuration for Concurrency
tf.config.threading.set_intra_op_parallelism_threads(1)
tf.config.threading.set_inter_op_parallelism_threads(1)
print("Environment set. TF restricted to 1 thread per instance to allow concurrency.")
# Out:
# Environment set. TF restricted to 1 thread per instance to allow concurrency.

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.astype(np.float32) / 255.0
X_test = X_test.astype(np.float32) / 255.0
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %%
def iid_partition(x, y, num_clients):
    idx = np.random.permutation(len(x))
    x_shuffled, y_shuffled = x[idx], y[idx]
    x_parts = np.array_split(x_shuffled, num_clients)
    y_parts = np.array_split(y_shuffled, num_clients)
    partitions = list(zip(x_parts, y_parts))
    return partitions

# %%
def non_iid_partition(x, y, num_clients):
    sorted_idx = np.argsort(y)
    X_sorted, Y_sorted = x[sorted_idx], y[sorted_idx]
    num_shards = 2 * num_clients
    size_shards = len(x) // num_shards
    shards_idx = np.random.permutation(num_shards)
    partitions = []
    for i in range(num_clients):
        s1, s2 = shards_idx[2*i], shards_idx[2*i+1]
        X_client = np.concatenate((X_sorted[s1*size_shards:(s1+1)*size_shards], X_sorted[s2*size_shards:(s2+1)*size_shards]), axis=0)
        Y_client = np.concatenate((Y_sorted[s1*size_shards:(s1+1)*size_shards], Y_sorted[s2*size_shards:(s2+1)*size_shards]), axis=0)
        idx = np.random.permutation(len(X_client))
        partitions.append((X_client[idx], Y_client[idx]))
    return partitions

# %%
# 4. Model Generation
def cnn_model():
    model = Sequential([
        Input(shape=(28, 28, 1)),
        Conv2D(32, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax'),
    ])
    model.compile(optimizer=SGD(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def local_training(client_data, global_weights, mu):
    X_local, Y_local = client_data
    num_sample = len(X_local)
    model = cnn_model()
    model.set_weights(global_weights)
    optimizer = SGD(learning_rate=0.01)
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
    global_weights_tensors = [tf.constant(w) for w in global_weights]
    dataset = tf.data.Dataset.from_tensor_slices((X_local, Y_local)).batch(32)
    
    def train_step(x, y):
        with tf.GradientTape() as tape:
            y_pred = model(x, training=True)
            base_loss = loss_fn(y, y_pred)
            
            proximal_term = 0.0
            for local_var, global_var in zip(model.trainable_variables, global_weights_tensors):
                proximal_term += tf.reduce_sum(tf.square(local_var - global_var))
                
            total_loss = base_loss + (mu / 2.0) * proximal_term    
        grads = tape.gradient(total_loss, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

    for epoch in range(2):
        for batch_x, batch_y in dataset:
            train_step(batch_x, batch_y)
            
    return model.get_weights(), num_sample

# %%
def aggregate_weights(client_updates, global_weights):
    tot_sample = sum(num_samples for _, num_samples in client_updates)
    new_weights = [np.zeros_like(w) for w in global_weights]
    
    for local_weights, num_samples in client_updates:
        w_factor = num_samples / tot_sample
        for i in range(len(new_weights)):
            new_weights[i] += local_weights[i] * w_factor
            
    return new_weights

# %%
def evaluate_global(global_model, X_test, Y_test):
    loss, accuracy = global_model.evaluate(X_test, Y_test, verbose=1)
    return loss, accuracy

# %%
def run_simulation(partitions, X_test, Y_test, num_clients, rounds, participation_rate, mu):
    global_model = cnn_model()
    global_weights = global_model.get_weights()
    max_workers = min(num_clients, 12)
    history = []
    
    for r in range(1, rounds + 1):
        num_active = max(1, int(num_clients * participation_rate))
        active_clients = random.sample(range(num_clients), num_active)
        client_updates = []
        
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            futures = [executor.submit(local_training, partitions[i], global_weights, mu) for i in active_clients]
            for future in futures:
                client_updates.append(future.result())
                
        # Aggregate and Update
        global_weights = aggregate_weights(client_updates, global_weights)
        global_model.set_weights(global_weights)
        
        # Evaluate
        loss, acc = evaluate_global(global_model, X_test, Y_test)
        history.append({'round': r, 'loss': loss, 'acc': acc})
        print(f"Round {r} | Accuracy: {acc} | Loss: {loss}")
        
    return history

# %%
CLIENTS=10
ROUNDS=20
PARTICIPATION_RATE =1
MU=0.1
    
print(f"=== RUNNING IID FEDPROX ({CLIENTS} Clients, {PARTICIPATION_RATE*100}% Participation) ===")
iid_parts = iid_partition(X_train, Y_train, CLIENTS)
iid_history = run_simulation(iid_parts, X_test, Y_test, CLIENTS, ROUNDS, PARTICIPATION_RATE, MU)
    
print(f"\n=== RUNNING NON-IID FEDPROX ({CLIENTS} Clients, {PARTICIPATION_RATE*100}% Participation) ===")
non_iid_parts = non_iid_partition(X_train, Y_train, CLIENTS)
non_iid_history = run_simulation(non_iid_parts, X_test, Y_test, CLIENTS, ROUNDS, PARTICIPATION_RATE, MU)
# Out:
# === RUNNING IID FEDPROX (10 Clients, 100% Participation) ===
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8574 - loss: 0.5293
# Round 1 | Accuracy: 0.8574000000953674 | Loss: 0.5292553305625916
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9161 - loss: 0.2991
# Round 2 | Accuracy: 0.916100025177002 | Loss: 0.29914677143096924
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9352 - loss: 0.2281
# Round 3 | Accuracy: 0.9351999759674072 | Loss: 0.2281060516834259
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9459 - loss: 0.1875
# Round 4 | Accuracy: 0.945900022983551 | Loss: 0.1874927580356598
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9540 - loss: 0.1592
# Round 5 | Accuracy: 0.9539999961853027 | Loss: 0.15918265283107758
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9621 - loss: 0.1387
# Round 6 | Accuracy: 0.9621000289916992 | Loss: 0.13868652284145355
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9647 - loss: 0.1231
# Round 7 | Accuracy: 0.9646999835968018 | Loss: 0.12306681275367737
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9671 - loss: 0.1111
# Round 8 | Accuracy: 0.9671000242233276 | Loss: 0.11112132668495178
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9700 - loss: 0.1017
# Round 9 | Accuracy: 0.9700000286102295 | Loss: 0.10169193893671036
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9725 - loss: 0.0940
# Round 10 | Accuracy: 0.9725000262260437 | Loss: 0.09399763494729996
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9735 - loss: 0.0878
# Round 11 | Accuracy: 0.9735000133514404 | Loss: 0.0877542719244957
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9753 - loss: 0.0825
# Round 12 | Accuracy: 0.9753000140190125 | Loss: 0.08251187950372696
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9764 - loss: 0.0781
# Round 13 | Accuracy: 0.9764000177383423 | Loss: 0.07810439169406891
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9765 - loss: 0.0744
# Round 14 | Accuracy: 0.9764999747276306 | Loss: 0.07435784488916397
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9778 - loss: 0.0712
# Round 15 | Accuracy: 0.9778000116348267 | Loss: 0.07115661352872849
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9783 - loss: 0.0683
# Round 16 | Accuracy: 0.9782999753952026 | Loss: 0.06827837228775024
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9791 - loss: 0.0657
# Round 17 | Accuracy: 0.9790999889373779 | Loss: 0.06571715325117111
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9798 - loss: 0.0633
# Round 18 | Accuracy: 0.9797999858856201 | Loss: 0.06330471485853195
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9807 - loss: 0.0612
# Round 19 | Accuracy: 0.9807000160217285 | Loss: 0.06123557686805725
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9813 - loss: 0.0593
# Round 20 | Accuracy: 0.9812999963760376 | Loss: 0.059345390647649765
#
# === RUNNING NON-IID FEDPROX (10 Clients, 100% Participation) ===
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.2721 - loss: 1.9286
# Round 1 | Accuracy: 0.2721000015735626 | Loss: 1.9286096096038818
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5397 - loss: 1.3318
# Round 2 | Accuracy: 0.5396999716758728 | Loss: 1.331825852394104
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6650 - loss: 0.9997
# Round 3 | Accuracy: 0.6650000214576721 | Loss: 0.9996635913848877
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7429 - loss: 0.8101
# Round 4 | Accuracy: 0.742900013923645 | Loss: 0.8101388216018677
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7829 - loss: 0.6919
# Round 5 | Accuracy: 0.7828999757766724 | Loss: 0.691886305809021
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8121 - loss: 0.6083
# Round 6 | Accuracy: 0.8120999932289124 | Loss: 0.608320951461792
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8332 - loss: 0.5469
# Round 7 | Accuracy: 0.8331999778747559 | Loss: 0.5469220876693726
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8460 - loss: 0.5000
# Round 8 | Accuracy: 0.8460000157356262 | Loss: 0.4999508857727051
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8563 - loss: 0.4655
# Round 9 | Accuracy: 0.8562999963760376 | Loss: 0.46548032760620117
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8663 - loss: 0.4343
# Round 10 | Accuracy: 0.8662999868392944 | Loss: 0.4342850148677826
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8763 - loss: 0.4064
# Round 11 | Accuracy: 0.8762999773025513 | Loss: 0.4063732922077179
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8821 - loss: 0.3840
# Round 12 | Accuracy: 0.882099986076355 | Loss: 0.3840269148349762
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8882 - loss: 0.3633
# Round 13 | Accuracy: 0.8881999850273132 | Loss: 0.3632642924785614
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8936 - loss: 0.3456
# Round 14 | Accuracy: 0.8935999870300293 | Loss: 0.3455946445465088
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8976 - loss: 0.3303
# Round 15 | Accuracy: 0.897599995136261 | Loss: 0.3302971422672272
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9006 - loss: 0.3170
# Round 16 | Accuracy: 0.900600016117096 | Loss: 0.316989541053772
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9041 - loss: 0.3041
# Round 17 | Accuracy: 0.9041000008583069 | Loss: 0.3040549159049988
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9067 - loss: 0.2935
# Round 18 | Accuracy: 0.9067000150680542 | Loss: 0.2934649586677551
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9099 - loss: 0.2828
# Round 19 | Accuracy: 0.9099000096321106 | Loss: 0.2828371226787567
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9134 - loss: 0.2734
# Round 20 | Accuracy: 0.9133999943733215 | Loss: 0.2733907997608185

# %%
iid_df = pd.DataFrame(iid_history)
non_iid_df = pd.DataFrame(non_iid_history)
    
plt.figure(figsize=(12, 5))
    
plt.subplot(1, 2, 1)
plt.plot(iid_df['round'], iid_df['acc'], marker='o', color='blue', label='Test Accuracy')
plt.plot(iid_df['round'], iid_df['loss'], marker='s', color='orange', label='Test Loss')
plt.title("Adaptive FedProx (IID)")
plt.xlabel("Communication Rounds")
plt.ylabel("Value")
plt.xticks(range(0, ROUNDS + 1, 2))
plt.legend()
plt.grid(True)
    
plt.subplot(1, 2, 2)
plt.plot(non_iid_df['round'], non_iid_df['acc'], marker='o', color='blue', label='Test Accuracy')
plt.plot(non_iid_df['round'], non_iid_df['loss'], marker='s', color='orange', label='Test Loss')
plt.title("Adaptive FedProx (Non-IID)")
plt.xlabel("Communication Rounds")
plt.ylabel("Value")
plt.xticks(range(0, ROUNDS + 1, 2))
plt.legend()
plt.grid(True)
    
plt.tight_layout()
plt.show()
